# %%
DATASET_PATH = "./data/prompt_complexity_dataset_2.csv"

import pandas as pd

df = pd.read_csv(DATASET_PATH)

df.head()
# Out:
#                                          prompt_text  token_count  \
# 0  Help me think through the tradeoffs of switchi...           18
# 1  Help a nonprofit decide between two vendors fo...           15
# 2  Sort these transactions into expense categorie...           13
# 3     Summarize the key takeaways from this contract           11
# 4  Help me think through the tradeoffs of switchi...           19
#
#    complexity_terms   turn_type  context_provided  context_window  \
# 0             False    one_shot              True           32000
# 1             False  multi_turn              True           16000
# 2             False    one_shot              True            4096
# 3              True    one_shot              True            8192
# 4             False  multi_turn             False               0
#
#         task_type  tier
# 0           Other     2
# 1           Other     3
# 2  Classification     2
# 3   Summarization     2
# 4           Other     3

# %%
X = df.iloc[:, 0, 8]
y = df.iloc[:, 8]
